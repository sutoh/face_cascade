# %%
import cv2
face_cascade = cv2.CascadeClassifier('./haar/haarcascade_frontalface_default.xml')
img = cv2.imread('./img/869616480.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[124, 118, 110, ..., 221, 229, 226],
#        [165, 162, 157, ..., 230, 230, 220],
#        [182, 182, 182, ..., 224, 228, 228],
#        ...,
#        [ 15,  15,  15, ..., 111, 117, 109],
#        [ 15,  15,  15, ..., 107, 114, 108],
#        [ 15,  15,  15, ..., 104, 112, 106]], dtype=uint8)

# %%
cv2.imwrite("./img/gray.jpg", gray)
# Out:
# True

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0,255,0), 2)

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
